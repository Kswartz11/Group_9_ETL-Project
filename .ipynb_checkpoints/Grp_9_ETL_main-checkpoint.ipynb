# %%
#Dependencies
import requests
from sqlalchemy import create_engine
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from config import api_key

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
cleaned_dataset_file = "Resources/cleaned_dataset.csv"
cleaned_dataset_df = pd.read_csv(cleaned_dataset_file)
cleaned_dataset_df
# Out:
#       Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0              0      1                       Inception  2010  13+   8.8
# 1              1      2                      The Matrix  1999  18+   8.7
# 2              2      3          Avengers: Infinity War  2018  13+   8.5
# 3              3      4              Back to the Future  1985   7+   8.5
# 4              4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...          ...    ...                             ...   ...  ...   ...
# 3296       16657  16658    A Kid in King Arthur's Court  1995   7+   4.7
# 3297       16671  16672          George of the Jungle 2  2003   7+   3.3
# 3298       16677  16678                   That Darn Cat  1997   7+   4.7
# 3299       16687  16688                          Kazaam  1996   7+   3.0
# 3300       16705  16706                Meet the Deedles  1998   7+   4.1
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                87%        1     0            0        0     0
# 1                87%        1     0            0        0     0
# 2                84%        1     0            0        0     0
# 3                96%        1     0            0        0     0
# 4                97%        1     0            1        0     0
# ...              ...      ...   ...          ...      ...   ...
# 3296              5%        0     0            0        1     0
# 3297             17%        0     0            0        1     0
# 3298             13%        0     0            0        1     0
# 3299              6%        0     0            0        1     0
# 3300              7%        0     0            0        1     0
#
#                            Directors                                   Genres  \
# 0                  Christopher Nolan         Action,Adventure,Sci-Fi,Thriller
# 1     Lana Wachowski,Lilly Wachowski                            Action,Sci-Fi
# 2            Anthony Russo,Joe Russo                  Action,Adventure,Sci-Fi
# 3                    Robert Zemeckis                  Adventure,Comedy,Sci-Fi
# 4                       Sergio Leone                                  Western
# ...                              ...                                      ...
# 3296                Michael Gottlieb  Adventure,Comedy,Family,Fantasy,Romance
# 3297                  David Grossman                  Adventure,Comedy,Family
# 3298                Robert Stevenson             Comedy,Crime,Family,Thriller
# 3299             Paul Michael Glaser            Comedy,Family,Fantasy,Musical
# 3300                     Steve Boyum                            Comedy,Family
#
#                                    Country                 Language  Runtime
# 0             United States,United Kingdom  English,Japanese,French    148.0
# 1                            United States                  English    136.0
# 2                            United States                  English    149.0
# 3                            United States                  English    116.0
# 4                 Italy,Spain,West Germany                  Italian    161.0
# ...                                    ...                      ...      ...
# 3296  United States,Hungary,United Kingdom                  English     89.0
# 3297               United States,Australia                  English     87.0
# 3298                         United States           English,French    116.0
# 3299                         United States                  English     93.0
# 3300                         United States                  English     93.0
#
# [3301 rows x 17 columns]

# %%
cleaned_dataset_df.dropna()
# Out:
#       Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0              0      1                       Inception  2010  13+   8.8
# 1              1      2                      The Matrix  1999  18+   8.7
# 2              2      3          Avengers: Infinity War  2018  13+   8.5
# 3              3      4              Back to the Future  1985   7+   8.5
# 4              4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...          ...    ...                             ...   ...  ...   ...
# 3296       16657  16658    A Kid in King Arthur's Court  1995   7+   4.7
# 3297       16671  16672          George of the Jungle 2  2003   7+   3.3
# 3298       16677  16678                   That Darn Cat  1997   7+   4.7
# 3299       16687  16688                          Kazaam  1996   7+   3.0
# 3300       16705  16706                Meet the Deedles  1998   7+   4.1
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                87%        1     0            0        0     0
# 1                87%        1     0            0        0     0
# 2                84%        1     0            0        0     0
# 3                96%        1     0            0        0     0
# 4                97%        1     0            1        0     0
# ...              ...      ...   ...          ...      ...   ...
# 3296              5%        0     0            0        1     0
# 3297             17%        0     0            0        1     0
# 3298             13%        0     0            0        1     0
# 3299              6%        0     0            0        1     0
# 3300              7%        0     0            0        1     0
#
#                            Directors                                   Genres  \
# 0                  Christopher Nolan         Action,Adventure,Sci-Fi,Thriller
# 1     Lana Wachowski,Lilly Wachowski                            Action,Sci-Fi
# 2            Anthony Russo,Joe Russo                  Action,Adventure,Sci-Fi
# 3                    Robert Zemeckis                  Adventure,Comedy,Sci-Fi
# 4                       Sergio Leone                                  Western
# ...                              ...                                      ...
# 3296                Michael Gottlieb  Adventure,Comedy,Family,Fantasy,Romance
# 3297                  David Grossman                  Adventure,Comedy,Family
# 3298                Robert Stevenson             Comedy,Crime,Family,Thriller
# 3299             Paul Michael Glaser            Comedy,Family,Fantasy,Musical
# 3300                     Steve Boyum                            Comedy,Family
#
#                                    Country                 Language  Runtime
# 0             United States,United Kingdom  English,Japanese,French    148.0
# 1                            United States                  English    136.0
# 2                            United States                  English    149.0
# 3                            United States                  English    116.0
# 4                 Italy,Spain,West Germany                  Italian    161.0
# ...                                    ...                      ...      ...
# 3296  United States,Hungary,United Kingdom                  English     89.0
# 3297               United States,Australia                  English     87.0
# 3298                         United States           English,French    116.0
# 3299                         United States                  English     93.0
# 3300                         United States                  English     93.0
#
# [3301 rows x 17 columns]

# %%
cleaned_dataset_df = cleaned_dataset_df[['ID','Title','Year','Age','IMDb','Netflix','Hulu','Disney+','Directors','Genres','Country','Language']].copy()
cleaned_dataset_df.head()
# Out:
#    ID                           Title  Year  Age  IMDb  Netflix  Hulu  \
# 0   1                       Inception  2010  13+   8.8        1     0
# 1   2                      The Matrix  1999  18+   8.7        1     0
# 2   3          Avengers: Infinity War  2018  13+   8.5        1     0
# 3   4              Back to the Future  1985   7+   8.5        1     0
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8        1     0
#
#    Disney+                       Directors                            Genres  \
# 0        0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1        0  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2        0         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3        0                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4        0                    Sergio Leone                           Western
#
#                         Country                 Language
# 0  United States,United Kingdom  English,Japanese,French
# 1                 United States                  English
# 2                 United States                  English
# 3                 United States                  English
# 4      Italy,Spain,West Germany                  Italian

# %%
cleaned_dataset_cols=['ID','Title','Year','Age','IMDb','Netflix','Hulu','Disney+','Directors','Genres','Country','Language']

cleaned_dataset_transformed= cleaned_dataset_df[cleaned_dataset_cols].copy()

cleaned_dataset_transformed = cleaned_dataset_transformed.rename(columns={'ID':'id',
                                                          'Title':'title',
                                                          'Year':'year',
                                                          'Age':'age',
                                                          'IMDb':'imdb',
                                                          'Netflix':'netflix',
                                                          'Hulu':'hulu',
                                                          'Disney+':'disney',
                                                          'Directors':'directors',
                                                          'Genres':'genres',
                                                          'Country':'country',
                                                          'Language':'language'})

cleaned_dataset_transformed.drop_duplicates('id', inplace=True)
cleaned_dataset_transformed.set_index('id', inplace=True)

cleaned_dataset_transformed.head()
# Out:
#                              title  year  age  imdb  netflix  hulu  disney  \
# id
# 1                        Inception  2010  13+   8.8        1     0       0
# 2                       The Matrix  1999  18+   8.7        1     0       0
# 3           Avengers: Infinity War  2018  13+   8.5        1     0       0
# 4               Back to the Future  1985   7+   8.5        1     0       0
# 5   The Good, the Bad and the Ugly  1966  18+   8.8        1     0       0
#
#                          directors                            genres  \
# id
# 1                Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 2   Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 3          Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 4                  Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 5                     Sergio Leone                           Western
#
#                          country                 language
# id
# 1   United States,United Kingdom  English,Japanese,French
# 2                  United States                  English
# 3                  United States                  English
# 4                  United States                  English
# 5       Italy,Spain,West Germany                  Italian

# %%
cleaned_dataset_API_file = "Resources/cleaned_dataset_API.csv"
cleaned_dataset_API_df = pd.read_csv(cleaned_dataset_API_file)
cleaned_dataset_API_df
# Out:
#                                Title  Year  Rated  \
# 0                          Inception  2010  PG-13
# 1                         The Matrix  1999      R
# 2             Avengers: Infinity War  2018  PG-13
# 3                 Back to the Future  1985     PG
# 4     The Good, the Bad and the Ugly  1966      R
# ...                              ...   ...    ...
# 3296                             NaN   NaN    NaN
# 3297                             NaN   NaN    NaN
# 3298                             NaN   NaN    NaN
# 3299                             NaN   NaN    NaN
# 3300                             NaN   NaN    NaN
#
#                                     Genre  \
# 0     Action, Adventure, Sci-Fi, Thriller
# 1                          Action, Sci-Fi
# 2               Action, Adventure, Sci-Fi
# 3               Adventure, Comedy, Sci-Fi
# 4                                 Western
# ...                                   ...
# 3296                                  NaN
# 3297                                  NaN
# 3298                                  NaN
# 3299                                  NaN
# 3300                                  NaN
#
#                                                  Actors  \
# 0     Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1     Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 2     Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 3     Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 4     Eli Wallach, Clint Eastwood, Lee Van Cleef, Al...
# ...                                                 ...
# 3296                                                NaN
# 3297                                                NaN
# 3298                                                NaN
# 3299                                                NaN
# 3300                                                NaN
#
#                                                    Plot  \
# 0     A thief who steals corporate secrets through t...
# 1     When a beautiful stranger leads computer hacke...
# 2     The Avengers and their allies must be willing ...
# 3     Marty McFly, a 17-year-old high school student...
# 4     A bounty hunting scam joins two men in an unea...
# ...                                                 ...
# 3296                                                NaN
# 3297                                                NaN
# 3298                                                NaN
# 3299                                                NaN
# 3300                                                NaN
#
#                        Language                          Country     imdbID  \
# 0     English, Japanese, French                          USA, UK  tt1375666
# 1                       English                              USA  tt0133093
# 2                       English                              USA  tt4154756
# 3                       English                              USA  tt0088763
# 4                       Italian  Italy, Spain, West Germany, USA  tt0060196
# ...                         ...                              ...        ...
# 3296                        NaN                              NaN        NaN
# 3297                        NaN                              NaN        NaN
# 3298                        NaN                              NaN        NaN
# 3299                        NaN                              NaN        NaN
# 3300                        NaN                              NaN        NaN
#
#          BoxOffice                                     Production
# 0     $292,576,195                          Syncopy, Warner Bros.
# 1     $171,479,930        Village Roadshow Prod., Silver Pictures
# 2     $678,815,482                                 Marvel Studios
# 3     $211,406,762       Universal Pictures, Amblin Entertainment
# 4      $25,100,000  Produzioni Europee Associati, Constantin Film
# ...            ...                                            ...
# 3296           NaN                                            NaN
# 3297           NaN                                            NaN
# 3298           NaN                                            NaN
# 3299           NaN                                            NaN
# 3300           NaN                                            NaN
#
# [3301 rows x 11 columns]

# %%
cleaned_dataset_API_df.dropna()
# Out:
#                                              Title  Year  Rated  \
# 0                                        Inception  2010  PG-13
# 1                                       The Matrix  1999      R
# 2                           Avengers: Infinity War  2018  PG-13
# 3                               Back to the Future  1985     PG
# 4                   The Good, the Bad and the Ugly  1966      R
# ..                                             ...   ...    ...
# 981  A Glimpse Inside the Mind of Charles Swan III  2012      R
# 983                                    Dance Flick  2009  PG-13
# 985                                 Jacob's Ladder  1990      R
# 987                 I'm in Love with a Church Girl  2013     PG
# 988                                    Poster Boys  2017  PG-13
#
#                                    Genre  \
# 0    Action, Adventure, Sci-Fi, Thriller
# 1                         Action, Sci-Fi
# 2              Action, Adventure, Sci-Fi
# 3              Adventure, Comedy, Sci-Fi
# 4                                Western
# ..                                   ...
# 981                               Comedy
# 983                Action, Comedy, Music
# 985               Drama, Horror, Mystery
# 987                Crime, Drama, Romance
# 988                               Comedy
#
#                                                 Actors  \
# 0    Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1    Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 2    Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 3    Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 4    Eli Wallach, Clint Eastwood, Lee Van Cleef, Al...
# ..                                                 ...
# 981  Charlie Sheen, James Paradise, Anne Bellamy, J...
# 983  Shoshana Bush, Damon Wayans Jr., Essence Atkin...
# 985  Tim Robbins, Elizabeth Peña, Danny Aiello, Mat...
# 987  Martin Kove, Michael Madsen, Zahn McClarnon, S...
# 988  Sunny Deol, Bobby Deol, Shreyas Talpade, Randh...
#
#                                                   Plot  \
# 0    A thief who steals corporate secrets through t...
# 1    When a beautiful stranger leads computer hacke...
# 2    The Avengers and their allies must be willing ...
# 3    Marty McFly, a 17-year-old high school student...
# 4    A bounty hunting scam joins two men in an unea...
# ..                                                 ...
# 981  A graphic designer's enviable life slides into...
# 983  Street dancer Thomas Uncles is from the wrong ...
# 985  Mourning his dead child, a haunted Vietnam War...
# 987  Miles Montego (Ja Rule) has it all - cars, boa...
# 988  Life of three men comes in trouble when their ...
#
#                       Language                          Country     imdbID  \
# 0    English, Japanese, French                          USA, UK  tt1375666
# 1                      English                              USA  tt0133093
# 2                      English                              USA  tt4154756
# 3                      English                              USA  tt0088763
# 4                      Italian  Italy, Spain, West Germany, USA  tt0060196
# ..                         ...                              ...        ...
# 981  English, Russian, Spanish                              USA  tt2044729
# 983                    English                              USA  tt1153706
# 985                    English                              USA  tt0099871
# 987                    English                              USA  tt1618432
# 988                      Hindi                            India  tt6352548
#
#         BoxOffice                                         Production
# 0    $292,576,195                              Syncopy, Warner Bros.
# 1    $171,479,930            Village Roadshow Prod., Silver Pictures
# 2    $678,815,482                                     Marvel Studios
# 3    $211,406,762           Universal Pictures, Amblin Entertainment
# 4     $25,100,000      Produzioni Europee Associati, Constantin Film
# ..            ...                                                ...
# 981       $45,350                                  American Zoetrope
# 983   $25,662,155                          Wayan Bros. Entertainment
# 985   $26,118,851                              Carolco Pictures Inc.
# 987    $2,387,730                             Reverence Gospel Media
# 988       $97,049  Affluence Movies, Sunny Sounds, Sony Pictures ...
#
# [527 rows x 11 columns]

# %%
cleaned_dataset_API_df = cleaned_dataset_API_df[['Title','Year','Rated','Genre','Actors','Plot','Language','Country','imdbID','BoxOffice','Production']].copy()
cleaned_dataset_API_df.head()
# Out:
#                             Title  Year  Rated  \
# 0                       Inception  2010  PG-13
# 1                      The Matrix  1999      R
# 2          Avengers: Infinity War  2018  PG-13
# 3              Back to the Future  1985     PG
# 4  The Good, the Bad and the Ugly  1966      R
#
#                                  Genre  \
# 0  Action, Adventure, Sci-Fi, Thriller
# 1                       Action, Sci-Fi
# 2            Action, Adventure, Sci-Fi
# 3            Adventure, Comedy, Sci-Fi
# 4                              Western
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 2  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 3  Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 4  Eli Wallach, Clint Eastwood, Lee Van Cleef, Al...
#
#                                                 Plot  \
# 0  A thief who steals corporate secrets through t...
# 1  When a beautiful stranger leads computer hacke...
# 2  The Avengers and their allies must be willing ...
# 3  Marty McFly, a 17-year-old high school student...
# 4  A bounty hunting scam joins two men in an unea...
#
#                     Language                          Country     imdbID  \
# 0  English, Japanese, French                          USA, UK  tt1375666
# 1                    English                              USA  tt0133093
# 2                    English                              USA  tt4154756
# 3                    English                              USA  tt0088763
# 4                    Italian  Italy, Spain, West Germany, USA  tt0060196
#
#       BoxOffice                                     Production
# 0  $292,576,195                          Syncopy, Warner Bros.
# 1  $171,479,930        Village Roadshow Prod., Silver Pictures
# 2  $678,815,482                                 Marvel Studios
# 3  $211,406,762       Universal Pictures, Amblin Entertainment
# 4   $25,100,000  Produzioni Europee Associati, Constantin Film

# %%
cleaned_dataset_API_cols=['Title','Rated','Actors','imdbID','BoxOffice','Production'] 

cleaned_dataset_API_transformed= cleaned_dataset_API_df[cleaned_dataset_API_cols].copy()

cleaned_dataset_API_transformed = cleaned_dataset_API_transformed.rename(columns={
                                                          'Title':'title',
                                                          'Rated':'rated',
                                                          'Actors':'actors',
                                                          'imdbID':'imdb_id',
                                                          'BoxOffice':'box_office',
                                                          'Production':'production'})

cleaned_dataset_API_transformed.set_index('title', inplace=True)

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:Predator@1702@localhost:5432/movies_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-2d97e9123e98> in <module>
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2317         """
#    2318
# -> 2319         with self._optional_conn_ctx_manager(connection) as conn:
#    2320             return self.dialect.get_table_names(conn, schema)
#    2321
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2087     def _optional_conn_ctx_manager(self, connection=None):
#    2088         if connection is None:
# -> 2089             with self._contextual_connect() as conn:
#    2090                 yield conn
#    2091         else:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2303         return self._connection_cls(
#    2304             self,
# -> 2305             self._wrap_pool_connect(self.pool.connect, None),
#    2306             close_with_result=close_with_result,
#    2307             **kwargs
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
# -> 2342                 Connection._handle_dbapi_exception_noconnection(
#    2343                     e, dialect, self
#    2344                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1583         elif should_wrap:
# -> 1584             util.raise_(
#    1585                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1586             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         dialect = self.dialect
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#    2341             if connection is None:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~\anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# ### Load DataFrames into database

# %%
cleaned_dataset_transformed.to_sql(name='kaggle', con=engine, if_exists='append', index=True)

# %%
cleaned_dataset_API_transformed.to_sql(name='api', con=engine, if_exists='append', index=True)
