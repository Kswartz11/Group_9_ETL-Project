# %%
import pandas as pd

# %%
file_one = "MoviesOnStreamingPlatforms_updated.csv"
file_one_df = pd.read_csv(file_one)
file_one_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
file_one_df.count()
# Out:
# Unnamed: 0         16744
# ID                 16744
# Title              16744
# Year               16744
# Age                 7354
# IMDb               16173
# Rotten Tomatoes     5158
# Netflix            16744
# Hulu               16744
# Prime Video        16744
# Disney+            16744
# Type               16744
# Directors          16018
# Genres             16469
# Country            16309
# Language           16145
# Runtime            16152
# dtype: int64

# %%
one_df=file_one_df.dropna(how='any')

# %%
one_df.count()
# Out:
# Unnamed: 0         3301
# ID                 3301
# Title              3301
# Year               3301
# Age                3301
# IMDb               3301
# Rotten Tomatoes    3301
# Netflix            3301
# Hulu               3301
# Prime Video        3301
# Disney+            3301
# Type               3301
# Directors          3301
# Genres             3301
# Country            3301
# Language           3301
# Runtime            3301
# dtype: int64

# %%
one_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
one_df.to_csv ('cleaned_dataset.csv', index = False, header=True)

# %%
title_list = one_df['Title'].tolist()
title_list
# Out:
# ['Inception',
#  'The Matrix',
#  'Avengers: Infinity War',
#  'Back to the Future',
#  'The Good, the Bad and the Ugly',
#  'Spider-Man: Into the Spider-Verse',
#  'The Pianist',
#  'Django Unchained',
#  'Raiders of the Lost Ark',
#  'Inglourious Basterds',
#  'Taxi Driver',
#  '3 Idiots',
#  "Pan's Labyrinth",
#  'Room',
#  'Monty Python and the Holy Grail',
#  'Once Upon a Time in the West',
#  'Indiana Jones and the Last Crusade',
#  'Groundhog Day',
#  "The King's Speech",
#  'Her',
#  'There Will Be Blood',
#  'The Social Network',
#  'Dallas Buyers Club',
#  'The Perks of Being a Wallflower',
#  'Life of Brian',
#  'Ex Machina',
#  'Silver Linings Playbook',
#  'District 9',
#  'The Irishman',
#  'Moon',
#  'Marriage Story',
#  'Drive',
#  'Incredibles 2',
#  'Dangal',
#  'Klaus',
#  'Minority Report',
#  'Mystic River',
#  'Like Stars on Earth',
#  "Ferris Bueller's Day Off",
#  'Despicable Me',
#  'Hell or High Water',
#  'Sin City',
#  'Ip Man',
# ...

# %%
# Dependencies
import requests
from config import api_key

url = "http://www.omdbapi.com/?apikey=" + api_key + "&t="

# %%
responses = []

for title in title_list:
    title_data = requests.get(url + title).json()
    responses.append(title_data)
    #print(f'The director of {movie} is {movie_data["Director"]}')

# %%
omdb_df = pd.DataFrame(responses)
omdb_df
# Out:
#                                Title  Year  Rated     Released  Runtime  \
# 0                          Inception  2010  PG-13  16 Jul 2010  148 min
# 1                         The Matrix  1999      R  31 Mar 1999  136 min
# 2             Avengers: Infinity War  2018  PG-13  27 Apr 2018  149 min
# 3                 Back to the Future  1985     PG  03 Jul 1985  116 min
# 4     The Good, the Bad and the Ugly  1966      R  29 Dec 1967  178 min
# ...                              ...   ...    ...          ...      ...
# 3296                             NaN   NaN    NaN          NaN      NaN
# 3297                             NaN   NaN    NaN          NaN      NaN
# 3298                             NaN   NaN    NaN          NaN      NaN
# 3299                             NaN   NaN    NaN          NaN      NaN
# 3300                             NaN   NaN    NaN          NaN      NaN
#
#                                     Genre                         Director  \
# ...

# %%
omdb_df_1 = omdb_df[['Title', 'Year', 'Rated', 'Genre','Actors', 'Plot', 'Language', 'Country','imdbID','BoxOffice', 'Production']]
omdb_df_1.head()
# Out:
#                             Title  Year  Rated  \
# 0                       Inception  2010  PG-13
# 1                      The Matrix  1999      R
# 2          Avengers: Infinity War  2018  PG-13
# 3              Back to the Future  1985     PG
# 4  The Good, the Bad and the Ugly  1966      R
#
#                                  Genre  \
# 0  Action, Adventure, Sci-Fi, Thriller
# 1                       Action, Sci-Fi
# 2            Action, Adventure, Sci-Fi
# 3            Adventure, Comedy, Sci-Fi
# 4                              Western
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
# 2  Robert Downey Jr., Chris Hemsworth, Mark Ruffa...
# 3  Michael J. Fox, Christopher Lloyd, Lea Thompso...
# 4  Eli Wallach, Clint Eastwood, Lee Van Cleef, Al...
#
#                                                 Plot  \
# 0  A thief who steals corporate secrets through t...
# ...

# %%
omdb_df_1.count()
# Out:
# Title         967
# Year          967
# Rated         967
# Genre         967
# Actors        967
# Plot          967
# Language      967
# Country       967
# imdbID        967
# BoxOffice     961
# Production    961
# dtype: int64

# %%
omdb_df_1.to_csv ('cleaned_dataset_API.csv', index = False, header=True)

# %%
# Dependencies
import requests
from config import api_key

url = "http://www.omdbapi.com/?apikey=" + api_key + "&t="

movies = ["Inception", "The Matrix"]

responses = []

for movie in movies:
    movie_data = requests.get(url + movie).json()
    responses.append(movie_data)
    print(movie_data)
# Out:
# {'Title': 'Inception', 'Year': '2010', 'Rated': 'PG-13', 'Released': '16 Jul 2010', 'Runtime': '148 min', 'Genre': 'Action, Adventure, Sci-Fi, Thriller', 'Director': 'Christopher Nolan', 'Writer': 'Christopher Nolan', 'Actors': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page, Tom Hardy', 'Plot': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O.', 'Language': 'English, Japanese, French', 'Country': 'USA, UK', 'Awards': 'Won 4 Oscars. Another 153 wins & 220 nominations.', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '87%'}, {'Source': 'Metacritic', 'Value': '74/100'}], 'Metascore': '74', 'imdbRating': '8.8', 'imdbVotes': '2,099,831', 'imdbID': 'tt1375666', 'Type': 'movie', 'DVD': '20 Jun 2013', 'BoxOffice
# ...

# %%
df = pd.DataFrame(responses)
df
# Out:
#         Title  Year  Rated     Released  Runtime  \
# 0   Inception  2010  PG-13  16 Jul 2010  148 min
# 1  The Matrix  1999      R  31 Mar 1999  136 min
#
#                                  Genre                         Director  \
# 0  Action, Adventure, Sci-Fi, Thriller                Christopher Nolan
# 1                       Action, Sci-Fi  Lana Wachowski, Lilly Wachowski
#
#                             Writer  \
# 0                Christopher Nolan
# 1  Lilly Wachowski, Lana Wachowski
#
#                                               Actors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Keanu Reeves, Laurence Fishburne, Carrie-Anne ...
#
#                                                 Plot  ... Metascore  \
# 0  A thief who steals corporate secrets through t...  ...        74
# 1  When a beautiful stranger leads computer hacke...  ...        73
#
#   imdbRating  imdbVotes     imdbID   Type          DVD     BoxOffice  \
# ...
